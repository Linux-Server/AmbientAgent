# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gpt-5-nano",
    
)

# %%
model.invoke("Tell me a joke?")
# Out:
# AIMessage(content='Here are a few jokes—pick your vibe:\n\n- Why don’t scientists trust atoms? Because they make up everything.\n- Why did the scarecrow win an award? Because he was outstanding in his field.\n- Parallel lines have so much in common. It’s a shame they’ll never meet.\n- I would tell you a chemistry joke, but I know I wouldn’t get a reaction.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 792, 'prompt_tokens': 11, 'total_tokens': 803, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1wNeuJHFESwawA1kPXaepdxvQ9DT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bf5c8-752f-7ad2-821c-8fae5cea9fa1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 792, 'total_tokens': 803, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})

# %%
for chunk in model.stream("Tell me a joke?"):
    for block in chunk.content_blocks:
        if block["type"] == "reasoning" and (reasoning := block.get("reasoning")):
            print(f"Reasoning: {reasoning}")
        else:
            print(block["text"], end="")
# Out:
# Here are a few quick ones:
#
# - Why don’t scientists trust atoms? Because they make up everything.
# - What do you call fake spaghetti? An impasta.
# - Why did the scarecrow win an award? He was outstanding in his field.
# - Why did the bicycle fall over? It was two-tired.
# - What do you call cheese that isn’t yours? Nacho cheese.
#
# Want a different style—dad jokes, nerdy, or puns?

# %%
responses = model.batch_as_completed([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# (0, AIMessage(content='Parrots look colorful mainly because of two things: pigments in their feathers and tiny light-reflecting structures inside the feathers. Here’s a quick breakdown:\n\n- Pigments:\n  - Carotenoids (from fruits, seeds, and vegetation) give reds, oranges, and yellows.\n  - Melanin adds blacks and browns.\n  - Some pigments called pterins also contribute to yellows and reds.\n  - The bird’s diet affects how bright these colors are.\n\n- Structural color:\n  - Some blues and greens come from microscopic structures in the feathers that reflect and scatter light in specific ways, sometimes working with pigments to produce vivid tones (for example, green often comes from yellow pigments plus blue structural color).\n\n- Why they’re colorful:\n  - Mate attraction and signaling health: brighter, more intense colors can indicate a healthy, good-for-daging mate.\n  - Species recognition and social signaling: colors help parrots recognize each other and communicate within flocks.\n  - Camouflage in their habitat: certain green patterns help them blend into leafy environments.\n  - Sex differences and age: in some species, males are more colorful to attract mates; juveniles may be duller.\n\n- Trade-offs:\n  - Bright colors can attract predators, so the color balance is a result of evolution, diet, and ecology.\n\nIf you want, I can give examples from specific parrot species (like macaws or cockatoos) to illustrate these ideas.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1329, 'prompt_tokens': 14, 'total_tokens': 1343, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1wUjLWz8axV52OaoU8H7azQm9QOv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bf5cf-29a3-7c41-b0bb-47ccc89668a6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 1329, 'total_tokens': 1343, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}}))
# (2, AIMessage(content='Quantum computing is a type of computing that uses the rules of quantum mechanics to process information. Instead of classical bits that are either 0 or 1, quantum computers use quantum bits or qubits, which can be 0, 1, or both at the same time (a property called superposition).\n\nKey ideas:\n- Superposition: A qubit can encode more information than a classical bit because it can be in a mix of 0 and 1.\n- Entanglement: Qubits can become correlated in ways that link their states, so the state of one qubit can depend on another, even when far apart.\n- Interference: The quantum state can interfere constructively or destructively to amplify correct answers and cancel out wrong ones.\n- Quantum gates: Operations that change the state of qubits, similar to logical gates in classical computers, but acting on superpositions.\n- Measurement: When you read the result, the qubits collapse to definite 0s or 1s.\n\nHow it differs from classical computing:\n- Quantum computers exploit superposition and entanglement to explore many possibilities in parallel.\n- They don’t magically solve all problems faster; they provide speedups for specific types of tasks.\n\nWhat quantum computers can do particularly well (in principle):\n- Shor’s algorithm for factoring large numbers (which could impact cryptography).\n- Grover’s algorithm for faster search in unsorted databases (quadratic speedup).\n- Simulating quantum systems, which is hard for classical computers but natural for quantum ones (useful in chemistry and materials science).\n- Some optimization problems and certain machine-learning tasks, under active research.\n\nCurrent state and challenges:\n- We are in the noisy intermediate-scale quantum (NISQ) era: devices have tens to a few hundred qubits but are noisy and not yet fault-tolerant.\n- Major challenges include quantum error correction, reducing errors (decoherence), and scaling up qubit counts in a reliable way.\n- There are several hardware approaches (including superconducting circuits, trapped ions, and photonic systems), but no universal, fault-tolerant quantum computer yet.\n\nIn short, quantum computing is a fundamentally new way of processing information that could solve certain problems more efficiently than classical computers, but it’s still in early stages and best suited for niche applications for now. If you’d like, I can give a simple example (like how Grover’s algorithm works conceptually) or explain a particular algorithm in more detail.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1343, 'prompt_tokens': 11, 'total_tokens': 1354, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1wUjjJda9uuHm91sAW09f6y5U0Ae', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bf5cf-29a7-7842-8a8f-a5428a959d40-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 1343, 'total_tokens': 1354, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}))
# (1, AIMessage(content='Airplanes stay up in the air mainly because of lift from the wings and forward thrust from the engines, while gravity pulls them down and drag slows them down. In steady flight, the lift balances weight and thrust balances drag.\n\nKey parts of the idea\n\n- Lift from the wings:\n  - Airfoil shape (curved on top, flatter on the bottom) makes air move faster over the top than the bottom.\n  - Faster air on top lowers pressure, and the difference in pressure pushes the wing upward.\n  - The wing also deflects air downward, and by Newton’s third law the plane gets an upward push.\n  - Lift depends on speed, wing area, air density, and the wing’s angle of attack (how much the nose is tilted up).\n\n- Thrust and drag:\n  - Engines provide forward thrust to move the plane through the air.\n  - Drag is the air resistance that slows the plane; thrust must overcome it for level flight or to accelerate.\n\n- The four forces in flight:\n  - Lift (up) vs. Weight (down)\n  - Thrust (forward) vs. Drag (backward)\n  - In level flight, Lift ≈ Weight and Thrust ≈ Drag.\n\n- How pilots control flight:\n  - Ailerons control roll (tilting wings left/right) to bank and turn.\n  - Elevators control pitch (nose up/down) to climb or descend.\n  - Rudder controls yaw (left/right direction) and coordinated turns.\n  - Flaps and slats are extra high-lift devices used during takeoff and landing to increase lift at lower speeds.\n\n- Stall and safe flight:\n  - If the wing’s angle of attack gets too high or the plane slows too much, lift drops suddenly (stall).\n  - Stall can be recovered by lowering the angle of attack and/or adding power to accelerate.\n\nA simple way to think about it: when the plane moves fast enough and the wings are tilted appropriately, they generate enough lift to support the weight, while the engines push the plane forward to keep that lift coming as you fly.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1844, 'prompt_tokens': 11, 'total_tokens': 1855, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D1wUjPEjhTS6r8e8ymumSocDietNw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bf5cf-29a5-7121-8a03-b3caec6a8d23-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 1844, 'total_tokens': 1855, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}}))
